# %%
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.naive_bayes import GaussianNB
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6195cc8c-dbaf-40b5-a1d1-086d2e6c8734" name="files[]" multiple disabled />
#      <output id="result-6195cc8c-dbaf-40b5-a1d1-086d2e6c8734">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agr_hi_dev.csv to agr_hi_dev.csv
# Saving agr_hi_fb_gold.csv to agr_hi_fb_gold.csv
# Saving agr_hi_train.csv to agr_hi_train.csv
# Saving agr_hi_tw_gold.csv to agr_hi_tw_gold.csv

# %%
Classifiers = [
    #LogisticRegression(C=0.000000001,solver='liblinear',max_iter=200),
    LogisticRegression()]
''' KNeighborsClassifier(15),
    SVC(kernel ='linear'),
    AdaBoostClassifier(),
    DecisionTreeClassifier(),
    RandomForestClassifier(n_estimators=200),
    SGDClassifier(max_iter=1000, tol=1e-3),
    GaussianNB(var_smoothing=1e-01),
    VotingClassifier(estimators=[('lr',LogisticRegression(solver='lbfgs', multi_class='multinomial',random_state=1,max_iter=200)),('rf', RandomForestClassifier(n_estimators=50, random_state=1)), 
                                 ('gnb', GaussianNB(var_smoothing=1e-01))], voting='hard'),
    VotingClassifier(estimators=[('dt', DecisionTreeClassifier()), ('knn', KNeighborsClassifier(15)), ('svc', SVC(gamma='scale', kernel ='linear', probability=True))],voting='soft')]'''
# Out:
# " KNeighborsClassifier(15),\n    SVC(kernel ='linear'),\n    AdaBoostClassifier(),\n    DecisionTreeClassifier(),\n    RandomForestClassifier(n_estimators=200),\n    SGDClassifier(max_iter=1000, tol=1e-3),\n    GaussianNB(var_smoothing=1e-01),\n    VotingClassifier(estimators=[('lr',LogisticRegression(solver='lbfgs', multi_class='multinomial',random_state=1,max_iter=200)),('rf', RandomForestClassifier(n_estimators=50, random_state=1)), \n                                 ('gnb', GaussianNB(var_smoothing=1e-01))], voting='hard'),\n    VotingClassifier(estimators=[('dt', DecisionTreeClassifier()), ('knn', KNeighborsClassifier(15)), ('svc', SVC(gamma='scale', kernel ='linear', probability=True))],voting='soft')]"

# %%
data=pd.read_csv("agr_hi_train.csv")

# %%
data.columns = ['Id','Comment', 'Aggression']

# %%
import re
'''import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')'''
# Out:
# "import nltk\nfrom nltk.corpus import stopwords\nnltk.download('stopwords')"

# %%
def tweet_to_words(raw_tweet):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet) 
    words = letters_only.lower().split()
    return( " ".join(words))

# %%
#data['Comment']=data['Comment'].apply(lambda x: tweet_to_words(x))

# %%
df=pd.DataFrame([data['Comment'],data['Aggression']]).T

# %%
data_test=pd.read_csv("agr_hi_dev.csv")
data_test.columns = ['Id','Comment', 'Aggression']
df1=pd.DataFrame([data_test['Comment'],data_test['Aggression']]).T

# %%
frames = [df["Comment"], df1["Comment"]]
result = pd.DataFrame(pd.concat(frames))
result.head()
# Out:
#                                              Comment
# 0  Bhai 60sal pehle desh me kya tha pehle pta kro...
# 1  chutiya friday ko isliye releae krte kyoki wee...
# 2                                         जय मोदीराज
# 3     UPA walo ne bahot kuch kr diya tha desh k liye
# 4  Pan ko Aadhar se link ki zarurat kuy hai? Supr...

# %%
result.shape
# Out:
# (14999, 1)

# %%
feature_extraction = TfidfVectorizer()
data_train = feature_extraction.fit_transform(result["Comment"].values.astype('U'))
#data_train.shape
data_train_1=data_train[0:11999,:]
data_train_2=df['Aggression']
data_train_1.shape
# Out:
# (11999, 29497)

# %%
data_test_1=data_train[11999:,:]
data_test_2=df1["Aggression"]
data_test_1.shape
# Out:
# (3000, 29497)

# %%
'''dense_features=data_train_1.toarray()
dense_test_1= data_test_1.toarray()
Accuracy=[]
Model=[]
for classifier in Classifiers:
    try:
        fit = classifier.fit(data_train_1,data_train_2)
        pred = fit.predict(data_test_1)
    except Exception:
        fit = classifier.fit(dense_features,data_train_2)
        pred = fit.predict(dense_test_1)
    class_report = classification_report(data_test_2,pred)
    print(class_report)
    conf=confusion_matrix(data_test_2, pred)
    print(conf)
    accuracy = accuracy_score(pred,data_test_2)
    Accuracy.append(accuracy)
    Model.append(classifier.__class__.__name__)
    print('Accuracy of '+classifier.__class__.__name__+'is '+str(accuracy))'''
# Out:
# "dense_features=data_train_1.toarray()\ndense_test_1= data_test_1.toarray()\nAccuracy=[]\nModel=[]\nfor classifier in Classifiers:\n    try:\n        fit = classifier.fit(data_train_1,data_train_2)\n        pred = fit.predict(data_test_1)\n    except Exception:\n        fit = classifier.fit(dense_features,data_train_2)\n        pred = fit.predict(dense_test_1)\n    class_report = classification_report(data_test_2,pred)\n    print(class_report)\n    conf=confusion_matrix(data_test_2, pred)\n    print(conf)\n    accuracy = accuracy_score(pred,data_test_2)\n    Accuracy.append(accuracy)\n    Model.append(classifier.__class__.__name__)\n    print('Accuracy of '+classifier.__class__.__name__+'is '+str(accuracy))"

# %% [markdown]
# FaceBook Test

# %%
data_test=pd.read_csv("agr_hi_fb_gold.csv")
data_test.columns = ['Id','Comment', 'Aggression']
df2=pd.DataFrame([data_test['Comment'],data_test['Aggression']]).T

# %%
frames = [df["Comment"], df2["Comment"]]
result1 = pd.DataFrame(pd.concat(frames))
#result.head()

# %%
feature_extraction = TfidfVectorizer()
data_train = feature_extraction.fit_transform(result1["Comment"].values.astype('U'))
#data_train.shape
data_train_1=data_train[0:11999,:]
data_train_2=df['Aggression']
data_train_1.shape
# Out:
# (11999, 27155)

# %%
data_test_1=data_train[11999:,:]
data_test_2=df2["Aggression"]
data_test_1.shape
# Out:
# (969, 27155)

# %%
dense_features=data_train_1.toarray()
dense_test_1= data_test_1.toarray()
Accuracy=[]
Model=[]
for classifier in Classifiers:
    try:
        fit = classifier.fit(data_train_1,data_train_2)
        pred = fit.predict(data_test_1)
    except Exception:
        fit = classifier.fit(dense_features,data_train_2)
        pred = fit.predict(dense_test_1)
    class_report = classification_report(data_test_2,pred,digits=4)
    print(class_report)
    conf=confusion_matrix(data_test_2, pred)
    print(conf)
    accuracy = accuracy_score(pred,data_test_2)
    Accuracy.append(accuracy)
    Model.append(classifier.__class__.__name__)
    print('Accuracy of '+classifier.__class__.__name__+'is '+str(accuracy))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
#               precision    recall  f1-score   support
#
#          CAG     0.5619    0.7579    0.6454       413
#          NAG     0.8081    0.4103    0.5442       195
#          OAG     0.6294    0.5457    0.5846       361
#
#    micro avg     0.6089    0.6089    0.6089       969
#    macro avg     0.6665    0.5713    0.5914       969
# weighted avg     0.6366    0.6089    0.6024       969
#
# [[313  16  84]
#  [ 83  80  32]
#  [161   3 197]]
# Accuracy of LogisticRegressionis 0.608875128998968

# %% [markdown]
# Twitter Test

# %%
data_test=pd.read_csv("agr_hi_tw_gold.csv")
data_test.columns = ['Id','Comment', 'Aggression']
df3=pd.DataFrame([data_test['Comment'],data_test['Aggression']]).T

# %%
frames = [df["Comment"], df3["Comment"]]
result2 = pd.DataFrame(pd.concat(frames))
#result.head()

# %%
feature_extraction = TfidfVectorizer()
data_train = feature_extraction.fit_transform(result2["Comment"].values.astype('U'))
#data_train.shape
data_train_1=data_train[0:11999,:]
data_train_2=df['Aggression']
data_train_1.shape

# %%
data_test_1=data_train[11999:,:]
data_test_2=df3["Aggression"]
data_test_1.shape

# %%
dense_features=data_train_1.toarray()
dense_test_1= data_test_1.toarray()
Accuracy=[]
Model=[]
for classifier in Classifiers:
    try:
        fit = classifier.fit(data_train_1,data_train_2)
        pred = fit.predict(data_test_1)
    except Exception:
        fit = classifier.fit(dense_features,data_train_2)
        pred = fit.predict(dense_test_1)
    class_report = classification_report(data_test_2,pred)
    print(class_report)
    conf=confusion_matrix(data_test_2, pred)
    print(conf)
    accuracy = accuracy_score(pred,data_test_2)
    Accuracy.append(accuracy)
    Model.append(classifier.__class__.__name__)
    print('Accuracy of '+classifier.__class__.__name__+'is '+str(accuracy))

# %%
import numpy as np

# %% [markdown]
# ***Fast Text***

# %%
from gensim.models import FastText

# %%
type(data['Comment'])

# %%
'''#creating the modelvector of the specified size of 100
tr_model=FastText(data['Comment'],alpha=0.025,window=5,min_count=1,sg=1,min_n=3)
#seperating each word from the text
tr_word=tr_model.wv.vocab
#using dictionary to store those words and to access them later using Key
tr_dict=dict(zip(list(tr_word),tr_model[tr_word]))
Tr_Features = list(map(lambda y:list(np.sum(list(map(lambda x:list(tr_dict[x]),y)),axis=0)),data['Comment']))'''
